# %% [markdown]
# <a href="https://colab.research.google.com/github/Habtamuyihun561/MAIA/blob/main/trial_15_03_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **#How to load datasets on Google Colab**
# 1. Load datasets from your local device
# Go to the left corner of the page, click on the folder icon.
#
# Then, click on the upload icon. Choose the desired file you want to work with.
#
# 2. Alternatively, you can upload a file using these lines of code.

# %%
from google.colab import files
upload = files.upload()
# When you run the cell, you will receive a prompt to choose the files from your device.

# %% [markdown]
# A downside to this method is that you will have to reupload the file anytime you re-open Colab. So it is best you save a copy of this file in your google drive for easy access.
#
# 2. Load datasets from Google Drive
#
# To load files from your drive, you have to first mount your google drive using lines of codes. You can find the code snippet on the Colab page using this method.
#
# Click on the Insert tab on the left top corner then click on Code snippets

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
#You can now access all your datasets on your Drive directly on Colab.
# Out:
# Mounted at /gdrive
# /gdrive

# %% [markdown]
# 3. Load datasets from URL
#
# Get the URL that contains the dataset
#
# Read the URL using the following methods:
#
# We will be working with this URL https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv')

# %%
#Alternatively, you could make your code clean by writing it in the form below:
import pandas as pd
url = 'https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv'
data = pd.read_csv(url)

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)
